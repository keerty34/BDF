# %% [markdown]
# # PySpark Regression Algorithms
#
# This notebook is compatible with **Google Colab**.

# %% [markdown]
# ## Install PySpark (Run once in Colab)

# %%
# !pip -q install pyspark

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression, DecisionTreeRegressor, RandomForestRegressor, GBTRegressor

# %%
spark=SparkSession.builder.appName('Regression').getOrCreate()

# %%
data=[(1000,2,150000),(1200,2,180000),(1500,3,250000),(1800,3,300000),(2200,4,400000)]
df=spark.createDataFrame(data,['area','bedrooms','price'])

# %%
dataset=VectorAssembler(inputCols=['area','bedrooms'],outputCol='features').transform(df).select('features','price')
train,test=dataset.randomSplit([0.8,0.2],42)

# %%
LinearRegression(labelCol='price').fit(train).transform(test).show()

# %%
DecisionTreeRegressor(labelCol='price').fit(train).transform(test).show()

# %%
RandomForestRegressor(labelCol='price').fit(train).transform(test).show()

# %%
GBTRegressor(labelCol='price').fit(train).transform(test).show()
